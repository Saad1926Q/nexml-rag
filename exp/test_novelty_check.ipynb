# %% [markdown]
# # Test Novelty Check
# Testing the novelty analysis on a NACCER proposal

# %%
import sys
sys.path.append('..')

from scripts.doc_extractor import extract_text_images_tables
from app.llm import check_novelty
import asyncio

# %%
# Extract text from PDF
file_path = '../documents/NACCER_2024_RD_8535.pdf'
doc_list = extract_text_images_tables(file_path)

# Get the proposal text
proposal_text = doc_list[0].page_content

print(f"Extracted proposal text ({len(proposal_text)} characters)")
print("\nFirst 500 characters:")
print(proposal_text[:500])
# Out:
# 2025-11-28 23:55:06,287 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-11-28 23:55:06,452 - INFO - Going to convert document batch...
# 2025-11-28 23:55:06,452 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 2c28ec89b014192881c35ecb45b96fd8
# 2025-11-28 23:55:06,485 - INFO - Loading plugin 'docling_defaults'
# 2025-11-28 23:55:06,499 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2025-11-28 23:55:06,526 - INFO - Loading plugin 'docling_defaults'
# 2025-11-28 23:55:06,550 - INFO - Registered ocr engines: ['auto', 'easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2025-11-28 23:55:07,236 - INFO - Accelerator device: 'cpu'
# [INFO] 2025-11-28 23:55:07,253 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2025-11-28 23:55:07,273 [RapidOCR] download_file.py:60: File exists and is valid: D:\sih-project\nexml-rag\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2025-11-28 23:55:07,274 [RapidOCR] main.py:53: Using D:\sih-project\nexml-rag\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2025-11-28 23:55:07,416 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2025-11-28 23:55:07,419 [RapidOCR] download_file.py:60: File exists and is valid: D:\sih-project\nexml-rag\.venv\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2025-11-28 23:55:07,420 [RapidOCR] main.py:53: Using D:\sih-project\nexml-rag\.venv\Lib\site-packages\rapidocr\models\ch_ppocr_mobile_v2.0_cls_infer.onnx
# [INFO] 2025-11-28 23:55:07,532 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2025-11-28 23:55:07,547 [RapidOCR] download_file.py:60: File exists and is valid: D:\sih-project\nexml-rag\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# [INFO] 2025-11-28 23:55:07,548 [RapidOCR] main.py:53: Using D:\sih-project\nexml-rag\.venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.onnx
# 2025-11-28 23:55:07,887 - INFO - Auto OCR model selected rapidocr with onnxruntime.
# 2025-11-28 23:55:07,903 - INFO - Accelerator device: 'cpu'
# 2025-11-28 23:55:11,239 - INFO - Accelerator device: 'cpu'
# 2025-11-28 23:55:11,863 - INFO - Processing document NACCER_2024_RD_8535.pdf
# 2025-11-28 23:55:15,145 - INFO - Finished converting document NACCER_2024_RD_8535.pdf in 8.86 sec.
# Extracted proposal text (1229 characters)
#
# First 500 characters:
# ## Research Proposal: NACCER/2024/RD/8535
#
# ## Optimization of Flotation Process for Waste Minimization
#
# | Principal Investigator:   | Dr. Lakshmi Mehta   |
# |---------------------------|---------------------|
# | Institution:              | IISc Bangalore      |
# | Research Area:            | Mine Planning       |
# | Funding Source:           | CIL                 |
# | Duration:                 | 18 months           |
# | Submission Date:          | 2024-01-21          |
#
# ## Abstract
#
# The proposed study

# %%
# Run novelty check
print("Running novelty analysis...\n")
novelty_result = await check_novelty(proposal_text)

print("="*80)
print("NOVELTY ANALYSIS RESULT")
print("="*80)
print(novelty_result)
# Out:
# 2025-11-28 23:55:15,204 - INFO - Use pytorch device_name: cpu
# 2025-11-28 23:55:15,208 - INFO - Load pretrained SentenceTransformer: sentence-transformers/clip-ViT-B-32
# Running novelty analysis...
#
# Embedding type: <class 'list'>
# 2025-11-28 23:55:19,418 - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# ================================================================================
# NOVELTY ANALYSIS RESULT
# ================================================================================
# **NOVELTY ANALYSIS REPORT**
#
# **Research Proposal:** NACCER/2024/RD/8535
# **Title:** Optimization of Flotation Process for Waste Minimization
#
# **Evaluator:** [Your Name]
# **Date:** [Current Date]
#
# **Similar Past Proposals:**
#
# Based on the given information, there are no similar past proposals provided. However, for the sake of analysis, let's assume we have a database of past proposals submitted to NACCER.
#
# **Assumed Past Proposals:**
#
# 1. Proposal: NACCER/2022/RD/1234 (Title: "Flotation Process Optimization")
# 	* Principal Investigator: Dr. Kumar Patel
# 	* Institution: IIT Delhi
# 	* Funding Source: CIL
# 	* Duration: 12 months
# 	* Abstract: Developed a new flotation process for waste minimization.
# 2. Proposal: NACCER/2021/RD/5678 (Title: "Innovative Mine Planning")
# 	* Principal Investigator: Dr. Preeti Malhotra
# 	* Institution: IIT Kanpur
# 	* Funding Source: CIL
# 	* Duration: 18 months
# 	* Abstract: Investigated the application of AI in mine planning for sustainable mining practices.
#
# **Analysis:**
#
# **1. Key Similarities with Past Proposals:**
#
# * The current proposal aims to optimize the flotation process for waste minimization, which is similar to the proposal NACCER/2022/RD/1234.
# * The use of AI techniques in the current proposal is also similar to the proposal NACCER/2021/RD/5678.
#
# **2. Novel Aspects of the Current Proposal:**
#
# * The proposed methodology involves combining traditional methods with modern AI techniques for comprehensive analysis and implementation, which is a novel approach.
# * The focus on sustainable mining practices and environmental compliance is a new aspect, highlighting the importance of eco-friendly mining operations.
# * The proposed study aims to develop a novel methodology, which is an improvement over the existing methods mentioned in the past proposals.
#
# **3. Overall Novelty Assessment:**
#
# Based on the analysis, I assess the novelty of the current proposal as **HIGH**. The proposed methodology and focus on sustainable mining practices and environmental compliance are novel aspects that differentiate this proposal from the past proposals. The use of AI techniques and comprehensive analysis are also innovative approaches that contribute to the overall novelty of the proposal.
#
# **Recommendation:**
#
# The current proposal, NACCER/2024/RD/8535, has a high potential for novelty and innovation. The proposed methodology and focus on sustainable mining practices and environmental compliance are unique and address the current challenges in the mining industry. I recommend that the proposal be evaluated further and considered for funding.
